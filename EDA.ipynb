# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd

df1 = pd.read_parquet("direct_python_streaming/data/raw/declarations.parquet")
print(df1.head())
print(f"Total records available: {len(df1)}")
# Out:
#    disasterNumber state  incidentType           declarationDate  \
# 0            5529    OR          Fire  2024-08-09T00:00:00.000Z
# 1            5528    OR          Fire  2024-08-06T00:00:00.000Z
# 2            5527    OR          Fire  2024-08-02T00:00:00.000Z
# 3            4312    CA  Severe Storm  2017-05-02T00:00:00.000Z
# 4            4251    AL  Severe Storm  2016-01-21T00:00:00.000Z
#
#           incidentBeginDate           incidentEndDate declarationType  \
# 0  2024-08-08T00:00:00.000Z                      None              FM
# 1  2024-08-04T00:00:00.000Z                      None              FM
# 2  2024-08-02T00:00:00.000Z                      None              FM
# 3  2017-02-08T00:00:00.000Z  2017-02-11T00:00:00.000Z              DR
# 4  2015-12-23T00:00:00.000Z  2015-12-31T00:00:00.000Z              DR
#
#   femaDeclarationString  fyDeclared declarationTitle  ... placeCode  \
# 0                  None         NaN             None  ...      None
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209310 entries, 0 to 209309
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   disasterNumber            209310 non-null  int64
#  1   state                     209310 non-null  object
#  2   incidentType              209310 non-null  object
#  3   declarationDate           209310 non-null  object
#  4   incidentBeginDate         209310 non-null  object
#  5   incidentEndDate           207723 non-null  object
#  6   declarationType           209310 non-null  object
#  7   femaDeclarationString     69770 non-null   object
#  8   fyDeclared                69770 non-null   float64
#  9   declarationTitle          69770 non-null   object
#  10  ihProgramDeclared         69770 non-null   object
#  11  iaProgramDeclared         69770 non-null   object
#  12  paProgramDeclared         69770 non-null   object
# ...

# %%
df = pd.read_parquet("direct_python_streaming/data/raw/disaster_summaries.parquet")
print(df.head())
print(f"Total records available: {len(df)}")
# Out:
#    disasterNumber  totalNumberIaApproved  totalAmountIhpApproved  \
# 0            3601                    NaN                     NaN
# 1            3602                    NaN                     NaN
# 2            1981                 7469.0             95754618.67
# 3            1802                    NaN                     NaN
# 4            4317                 1978.0             12527583.31
#
#    totalAmountHaApproved  totalAmountOnaApproved  totalObligatedAmountPa  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2            93631947.01              2122671.66            2.243558e+08
# 3                    NaN                     NaN            1.881275e+07
# 4            10311780.12              2215803.19            7.731984e+07
#
#    totalObligatedAmountCatAb  totalObligatedAmountCatC2g  \
# 0                        NaN                         NaN
# ...

# %%
print(df.tail(10))
print(df.describe())
# Out:
#        disasterNumber state  incidentType           declarationDate  year  \
# 26690            4116    IL         Flood  2013-05-10T00:00:00.000Z  2013
# 26691            4116    IL         Flood  2013-05-10T00:00:00.000Z  2013
# 26692            4116    IL         Flood  2013-05-10T00:00:00.000Z  2013
# 26693            4114    IA  Severe Storm  2013-05-06T00:00:00.000Z  2013
# 26694            4114    IA  Severe Storm  2013-05-06T00:00:00.000Z  2013
# 26695            4114    IA  Severe Storm  2013-05-06T00:00:00.000Z  2013
# 26696            4114    IA  Severe Storm  2013-05-06T00:00:00.000Z  2013
# 26697            4114    IA  Severe Storm  2013-05-06T00:00:00.000Z  2013
# 26698            4113    MN  Severe Storm  2013-05-03T00:00:00.000Z  2013
# 26699            4113    MN  Severe Storm  2013-05-03T00:00:00.000Z  2013
#
#                      ingested_at
# 26690 2026-04-07 19:16:44.155555
# 26691 2026-04-07 19:16:44.290299
# 26692 2026-04-07 19:16:44.408148
# ...

# %%
df = pd.read_parquet("direct_python_streaming/data/raw/public_assistance.parquet")
print(df.head())
print(f"Total records available: {len(df)}")
# Out:
#    disasterNumber           declarationDate     incidentType  pwNumber  \
# 0            1239  1998-08-26T00:00:00.000Z  Severe Storm(s)         1
# 1            1239  1998-08-26T00:00:00.000Z  Severe Storm(s)         5
# 2            1239  1998-08-26T00:00:00.000Z  Severe Storm(s)         7
# 3            1239  1998-08-26T00:00:00.000Z  Severe Storm(s)         8
# 4            1239  1998-08-26T00:00:00.000Z  Severe Storm(s)        10
#
#                   applicationTitle   applicantId damageCategoryCode  \
# 0  (PW# 1) IMMEDIATE NEEDS FUNDING  465-19792-00                  B
# 1             (PW# 5) Not Provided  465-19792-00                  G
# 2             (PW# 7) Not Provided  465-19792-00                  G
# 3             (PW# 8) Not Provided  465-19792-00                  G
# 4            (PW# 10) Not Provided  465-19792-00                  G
#
#                              damageCategoryDescrip projectStatus  \
# ...
